# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   40G   69G  37% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.2G  817M  59% /sbin/docker-init
# tmpfs           6.4G   40K  6.4G   1% /var/colab
# /dev/sda1        81G   44G   38G  54% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# !ls /proc
# Out:
# 1     buddyinfo  execdomains  kpagecgroup  pagetypeinfo   sysvipc
# 137   bus	 filesystems  kpagecount   partitions	  thread-self
# 157   cgroups	 fs	      kpageflags   pressure	  timer_list
# 17    cmdline	 interrupts   loadavg	   schedstat	  tty
# 28    config.gz  iomem	      locks	   scsi		  uptime
# 29    consoles	 ioports      mdstat	   self		  version
# 42    cpuinfo	 irq	      meminfo	   slabinfo	  vmallocinfo
# 43    crypto	 kallsyms     misc	   softirqs	  vmstat
# 56    devices	 kcore	      modules	   stat		  zoneinfo
# 7     diskstats  keys	      mounts	   swaps
# 77    dma	 key-users    mtrr	   sys
# acpi  driver	 kmsg	      net	   sysrq-trigger

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13302920 kB
# MemFree:        10822536 kB
# MemAvailable:   12470448 kB
# Buffers:          108036 kB
# Cached:          1682932 kB
# SwapCached:            0 kB
# Active:           899476 kB
# Inactive:        1401964 kB
# Active(anon):     452728 kB
# Inactive(anon):      460 kB
# Active(file):     446748 kB
# Inactive(file):  1401504 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               192 kB
# Writeback:             0 kB
# AnonPages:        510448 kB
# Mapped:           250912 kB
# Shmem:              1184 kB
# KReclaimable:      82272 kB
# Slab:             123668 kB
# SReclaimable:      82272 kB
# SUnreclaim:        41396 kB
# KernelStack:        4848 kB
# PageTables:         7528 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6651460 kB
# Committed_AS:    3099888 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:        7216 kB
# VmallocChunk:          0 kB
# Percpu:             1448 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:       90944 kB
# DirectMap2M:     5148672 kB
# DirectMap1G:    10485760 kB

# %%
from tensorflow.python.client import device_lib
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2547089964993831541
#  xla_global_id: -1]

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# ''

# %%
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 13243493500031779775
#  xla_global_id: -1]
